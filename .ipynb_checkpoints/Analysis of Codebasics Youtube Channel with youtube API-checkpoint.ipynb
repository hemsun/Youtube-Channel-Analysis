# %%
from googleapiclient.discovery import build
import pandas as pd
from dateutil import parser
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from wordcloud import WordCloud
from wordcloud import STOPWORDS

# %%
api_key = 'AIzaSyDvFewNJOfe_FMaqPAJvo_GVdxMUQPV1sY'
channel_id= 'UCh9nVJoWXmFb7sLApWGcLPQ'

youtube= build('youtube','v3',developerKey= api_key)

# %%
# Function to get Chanbel stats

def get_channel_stats(youtube, channel_id):
    request = youtube.channels().list(
        part='statistics, snippet,contentDetails',
        id= channel_id
    )
    response= request.execute()
    
    data =dict(channel_name = response['items'][0]['snippet']['title'],
               subscriber_count = response['items'][0]['statistics']['subscriberCount'] ,
               views = response['items'][0]['statistics']['viewCount'],
               total_videos= response['items'][0]['statistics']['videoCount'],
               playlist_id = response['items'][0]['contentDetails']['relatedPlaylists']['uploads']
              )
    
    return data

# %%
get_channel_stats(youtube, channel_id)
# Out:
# {'channel_name': 'codebasics',
#  'subscriber_count': '819000',
#  'views': '56100712',
#  'total_videos': '623',
#  'playlist_id': 'UUh9nVJoWXmFb7sLApWGcLPQ'}

# %%
playlist_id = 'UUh9nVJoWXmFb7sLApWGcLPQ'

def get_video_ids(youtube, playlist_id):
    
    request = youtube.playlistItems().list(
        part='contentDetails',
        playlistId= playlist_id,
        maxResults=50
    )

    response= request.execute()
    #print (response)
    

    
    video_ids=[]
    
    for i in range(len(response['items'])):
        video_ids.append(response['items'][i]['contentDetails']['videoId'])
        
        
    next_page_token = response.get('nextPageToken')
    more_pages= True
    
    while more_pages:
        if next_page_token is None:
            more_pages= False
        else:
            request = youtube.playlistItems().list(
                                                    part='contentDetails',
                                                    playlistId= playlist_id,
                                                    maxResults=50,
                                                    pageToken=next_page_token
                                                )
            response=request.execute()
           
            for i in range(len(response['items'])):
                video_ids.append(response['items'][i]['contentDetails']['videoId'])
                
            next_page_token= response.get('nextPageToken')
            
            
            
            
        
    
    #return len(video_ids)
    return video_ids

# %%
video_ids=get_video_ids(youtube, playlist_id)

# %%
print(len(video_ids))
# Out:
# 624

# %%
# Function to get video details

def get_video_details(youtube,video_ids):
    
    all_video_stats=[]
    
    for i in range(0,len(video_ids),50):
        
    
        request = youtube.videos().list(
        part = 'snippet,statistics,contentDetails',
        id=','.join(video_ids[i:i+50]))

        response = request.execute()
        
        #print(response)
        
        for video in response['items']:
            video_stats = dict(Title= video['snippet']['title'],
                              Published_date =video['snippet']['publishedAt'],
                              Channel_title =video['snippet']['channelTitle'],
                              Views_count = video['statistics']['viewCount'],
                              Likes_count = video['statistics']['likeCount'],
                              Favorite_count = video['statistics']['favoriteCount'],
                              Comments_count = video['statistics']['commentCount'],
                              Duration = video['contentDetails']['duration'])
                              
            
            all_video_stats.append(video_stats)
            
            
            
    
   
    return all_video_stats

# %%
stats= get_video_details(youtube,video_ids)
print (len(stats))
# Out:
# 624

# %%
video_data= get_video_details(youtube,video_ids)

# %%
df=pd.DataFrame(video_data)

# %%
df.shape
# Out:
# (624, 8)

# %% [markdown]
# # Data Preprocessing

# %%
#checking for null values
df.isnull().any()
# Out:
# Title             False
# Published_date    False
# Channel_title     False
# Views_count       False
# Likes_count       False
# Favorite_count    False
# Comments_count    False
# Duration          False
# dtype: bool

# %%
#checking data types
df.dtypes
# Out:
# Title             object
# Published_date    object
# Channel_title     object
# Views_count       object
# Likes_count       object
# Favorite_count    object
# Comments_count    object
# Duration          object
# dtype: object

# %%
df.columns= df.columns.str.lower()

# %%
#converting all the count values to numeric
numeric_cols=['views_count','likes_count','favorite_count','comments_count']
df[numeric_cols] = df[numeric_cols].apply(pd.to_numeric, errors = 'coerce', axis = 1)
df['published_date']=pd.to_datetime(df['published_date']).dt.date

# %%
df.dtypes
# Out:
# title             object
# published_date    object
# channel_title     object
# views_count        int64
# likes_count        int64
# favorite_count     int64
# comments_count     int64
# duration          object
# dtype: object

# %%
df.head(10)
# Out:
#                                                title published_date  \
# 0  Business Math & Statistics Using Excel For Dat...     2023-07-21
# 1  How to use ChatGPT on your data - End to End P...     2023-07-12
# 2  OpenAI Api Crash Course For Beginners | Financ...     2023-07-05
# 3  LangChain Crash Course For Beginners | LangCha...     2023-06-30
# 4  End-to-End NLP Project | Build a Chatbot in Di...     2023-06-23
# 5  Resume Challenge #5 Winner Announcement: Provi...     2023-06-20
# 6    Introduction to Chatbots | NLP Tutorial | S3 E1     2023-06-16
# 7  How He Grew His Business 3X Using Data Analyti...     2023-06-01
# 8  Know this before you start learning any techno...     2023-05-27
# 9  Hacks for Moms With a Career Break to Become a...     2023-05-25
#
#   channel_title  views_count  likes_count  favorite_count  comments_count  \
# 0    codebasics         7220          267               0              28
# ...

# %%
# Publish day in the week
df['publish_day_name'] = df['published_date'].apply(lambda x: x.strftime("%A"))

# %%
df.head(2)
# Out:
#                                                title published_date  \
# 0  Business Math & Statistics Using Excel For Dat...     2023-07-21
# 1  How to use ChatGPT on your data - End to End P...     2023-07-12
#
#    views_count  likes_count  favorite_count  comments_count    duration  \
# 0         7115          264               0              28  PT1H24M49S
# 1        13960          369               0              32    PT42M47S
#
#   publish_day_name
# 0           Friday
# 1        Wednesday

# %%
#converting duration to seconds

import isodate
df['duration_Secs'] = df['duration'].apply(lambda x: isodate.parse_duration(x).total_seconds())

# %% [markdown]
# # Best performing videos

# %%
top_10_videos = df.sort_values(by='views_count',ascending=False ).head(10)
top_10_videos
# Out:
#                                                  title published_date  \
# 149  Reality behind data science, machine learning ...     2022-02-16
# 298  Bitcoin mining with 15 lines of python code Py...     2021-01-03
# 552  Python Pandas Tutorial 1. What is Pandas pytho...     2017-01-21
# 521  Machine Learning Tutorial Python -1: What is M...     2018-06-30
# 369  Complete python roadmap | How to become an exp...     2020-09-13
# 520  Machine Learning Tutorial Python - 2: Linear R...     2018-07-01
# 551         Python Pandas Tutorial 2: Dataframe Basics     2017-01-28
# 355  Simple explanation of convolutional neural net...     2020-10-14
# 226  He cracked FAANG (MAANG) interviews in 10 comp...     2021-06-19
# 375  8 Skills to get a data analyst job | Skills to...     2020-09-02
#
#      views_count  likes_count  favorite_count  comments_count  duration  \
# 149      1150793        55292               0             411     PT53S
# ...

# %%
ax1 = sns.barplot(x='views_count', y='title', data=top_10_videos)
ax1.xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos:'{:,.0f}'.format(x/1000) + 'K'))

# %% [markdown]
# # Worst performing videos

# %%
Bottom_10_videos = df.sort_values(by='views_count',ascending=True ).head(10)

# %%
ax1 = sns.barplot(x='views_count', y='title', data=Bottom_10_videos)
ax1.xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos:'{:,.0f}'.format(x/1000) + 'K'))

# %% [markdown]
# # upload schedule

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


# Creating a DataFrame with the count of videos for each day
days_df = pd.DataFrame(df['publish_day_name'].value_counts())

# Define the order of weekdays to ensure correct x-axis ordering
week_days = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']

# Reindex the DataFrame to include all weekdays and fill NaN values with 0
days_df = day_df.reindex(week_days, fill_value=0)

# Reset the index to have 'publish_day_name' as a separate column and rename the count column
days_df = days_df.reset_index()
days_df.columns = ['publish_day_name', 'count']

# Plotting the bar chart
ax = sns.barplot(x='publish_day_name', y='count', data=days_df)

# Adding labels to the axes and setting a title
ax.set(xlabel='Day', ylabel='Number of Videos', title='Videos Published on Each Day')

# Rotating the x-axis labels for better readability
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)

# Display the plot
plt.show()

# %%
"""we can see majority of the videos are published on Saturday followed by Wednesday"""

# %% [markdown]
# # Distribution of views

# %%
sns.violinplot(x=df['channel_title'], y=df['views_count'],data=df)
# Out:
# <AxesSubplot:xlabel='channel_title', ylabel='views_count'>

# %%
"""We can see there are some outlier videos with millions of views but majority of them 
lie within 200000""

# %% [markdown]
# # Average duration of videos

# %%
sns.histplot(data=df, x='duration_Secs',bins=30,kde=True
            )
# Out:
# <AxesSubplot:xlabel='duration_Secs', ylabel='Count'>

# %%
df['duration_Secs'].median()

#"""Most of the videos are between 12 to 20 mins , its right skewed """
# Out:
# 738.5

# %% [markdown]
# # wordcloud - Most used words in title

# %%
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from nltk.corpus import stopwords
import nltk
nltk.download('stopwords')


# Combine all 'title' texts into a single string for word cloud generation
all_titles_str = ' '.join(df['title'].tolist())

# Create a set of stop words for English
stop_words = set(stopwords.words('english'))

# Remove stop words from the text to make the word cloud more meaningful
filtered_titles_str = ' '.join([word for word in all_titles_str.split() if word.lower() not in stop_words])

# Generate the word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(filtered_titles_str)

# Plot the word cloud
plt.figure(figsize=(10, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')

# Display the plot
plt.show()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\hemal\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.

# %% [markdown]
# # Top 3 most liked video

# %%
top_3_likes = df.sort_values(by='likes_count',ascending=False ).head(3)
top_3_likes
# Out:
#                                                  title published_date  \
# 149  Reality behind data science, machine learning ...     2022-02-16
# 298  Bitcoin mining with 15 lines of python code Py...     2021-01-03
# 369  Complete python roadmap | How to become an exp...     2020-09-13
#
#     channel_title  views_count  likes_count  favorite_count  comments_count  \
# 149    codebasics      1150966        55300               0             411
# 298    codebasics      1085950        31630               0            3013
# 369    codebasics       851935        29873               0            1031
#
#      duration  duration_Secs
# 149     PT53S           53.0
# 298     PT25M         1500.0
# 369  PT13M22S          802.0

# %%
ax1 = sns.barplot(x='likes_count', y='title', data=top_3_likes)
ax1.xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos:'{:,.0f}'.format(x/1000) + 'K'))

# %%
# Top 3 videos with the highest comment

top_3_comments = df.sort_values(by='comments_count',ascending=False ).head(3)
top_3_comments
# Out:
#                                                  title published_date  \
# 298  Bitcoin mining with 15 lines of python code Py...     2021-01-03
# 462  Skills required for data analyst | How to lear...     2020-02-08
# 520  Machine Learning Tutorial Python - 2: Linear R...     2018-07-01
#
#     channel_title  views_count  likes_count  favorite_count  comments_count  \
# 298    codebasics      1085950        31630               0            3013
# 462    codebasics       538794        24325               0            2598
# 520    codebasics       797233        10684               0            1184
#
#      duration  duration_Secs
# 298     PT25M         1500.0
# 462  PT11M13S          673.0
# 520  PT15M14S          914.0

# %%
ax1 = sns.barplot(x='comments_count', y='title', data=top_3_comments)
ax1.xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos:'{:,.0f}'.format(x/1000) + 'K'))
